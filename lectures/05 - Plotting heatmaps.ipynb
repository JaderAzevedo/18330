# %%
using Plots

# %%
M = rand(10, 10)
# Out:
# 10×10 Matrix{Float64}:
#  0.501547  0.697142   0.650025   …  0.671394   0.632135    0.863297
#  0.175731  0.436779   0.298586      0.0739497  0.990438    0.455275
#  0.186994  0.515715   0.46876       0.0747897  0.0840026   0.090768
#  0.798963  0.394725   0.167145      0.222941   0.0211542   0.96582
#  0.808624  0.229743   0.49145       0.527505   0.534373    0.779518
#  0.242572  0.677869   0.0759293  …  0.522971   0.00492318  0.432316
#  0.978385  0.0639305  0.558095      0.5243     0.315352    0.152184
#  0.677366  0.800805   0.38997       0.347713   0.204392    0.0540149
#  0.536127  0.108335   0.0716925     0.0055985  0.757336    0.995583
#  0.221801  0.686653   0.812386      0.922408   0.230263    0.879087

# %%
heatmap(M, ratio=1)

# %%
heatmap(range(-1, 1, length=10), range(-1, 1, length=10), M, ratio=1)

# %%
surface(M)

# %%
]add PlotlyJS ORCA
# Out:
#     Updating registry at `C:\Users\jader\.julia\registries\General`
#    Resolving package versions...
#    Installed ORCA ─────── v0.5.0
#    Installed Hiccup ───── v0.2.2
#    Installed BinDeps ──── v1.0.2
#    Installed Lazy ─────── v0.15.1
#    Installed PlotlyBase ─ v0.4.3
#    Installed URIParser ── v0.4.1
#    Installed Mustache ─── v1.0.10
#    Installed Mux ──────── v0.7.5
#    Installed PlotlyJS ─── v0.14.0
#    Installed Blink ────── v0.12.4
# Updating `C:\Users\jader\.julia\environments\v1.6\Project.toml`
#   [47be7bcc] + ORCA v0.5.0
#   [f0f68f2c] + PlotlyJS v0.14.0
# Updating `C:\Users\jader\.julia\environments\v1.6\Manifest.toml`
#   [9e28174c] + BinDeps v1.0.2
#   [ad839575] + Blink v0.12.4
#   [9fb69e20] + Hiccup v0.2.2
#   [50d2b5c4] + Lazy v0.15.1
#   [ffc61752] + Mustache v1.0.10
#   [a975b10e] + Mux v0.7.5
#   [47be7bcc] + ORCA v0.5.0
#   [a03496cd] + PlotlyBase v0.4.3
#   [f0f68f2c] + PlotlyJS v0.14.0
#   [30578b45] + URIParser v0.4.1
# ...

# %%
plotlyjs()
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-15894328905777587843\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-2553493304446252199\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n   
# ...
